# %% [markdown]
# Escribir un programa que calcule las raices de
# ax^2 + bx + c = 0
#
# Esto lo puede hacer con la ecuacion general de segundo orden
# x1,2 =−b ±√b^2 − 4ac
#                2a
#
# Si el discriminante (b2 − 4ac) es negativo, entonces debe de imprimir
# Error, el discriminante tiene que se positivo
# y debe de volver a leer los valores de los coeficientes a, b y c, esto se debe de ciclar hasta que
# el discriminante sea positivo

# %%
a = float(input("Ingrese valor para X^2: "))
b = float(input("Ingrese valor para X: "))
c = float(input("Ingrese valor para c: "))

discri = ((b*b)-4 * a * c)

while (discri<0):
    print("Error, el discriminante tiene que ser positivo")

    a = float(input("Ingrese a: "))
    b = float(input("Ingrese b: "))
    c = float(input("Ingrese c: "))

    discri = ((b*b)-4 * a * c)

discri = ((b ** 2)-4 * a * c)
if (discri == 0):
    if (a>0 and b>0):
       x = -b/(2 * a)
       print ("La solucion unica es x =", x)
    else:
       print("X vale 0")   
else:
   x1 = (-b - (discri ** 0.5)) / (2 * a)
   x2 = (-b + (discri ** 0.5)) / (2 * a)
   print ("Las dos soluciones reales son:")
   print ("x1 =", x1)
   print ("x2 =", x2)

# %% [markdown]
# Sea la funcion
# f(x) = x^2 + 3x + 3
#
# Realizar un funcion que acepte como argumento el valor de x, que calcule el valor de f(x) y
# que lo regrese a la funcion principal.
# En el programa principal, debe de hacer un bucle que ayude a evaluar la funcion con valores
# desde -4 hasta 10 y que pare el bucle cuando el valor e f(x) sea mayor a 30.
# Guardar en una lista el valor de las iteraciones conforme van pasando.
# Pistas: Debes de utilizar el bucle while con un contador que comienza en -4 y debe de ir sumando en uno.
# La lista vacia se declara con miLista=[] y cada que quieras agregar alg´un elemento te conviene
# utilizar .append(valor).

# %%
def funcion(x):
  res=(x*x)+(3*x)+3
  return [res]

MiLista=[]

print("En la función f(x) = x^2 + 3x + 3")

contador=-4
l=10
while (contador<=l):    
  a=contador
  x=-4
  while (a==3 and x<=3):   

    y=funcion(x)
    print("Tu función es: ",x,"^ 2 + 3 *",x,"+ 3 =",y)
    t=y
    x=x+1 
    MiLista.append(t)
   
  contador += 1  

print("Los valores guardados son: ",MiLista)
# Out:
# En la función f(x) = x^2 + 3x + 3
# Tu función es:  -4 ^ 2 + 3 * -4 + 3 = [7]
# Tu función es:  -3 ^ 2 + 3 * -3 + 3 = [3]
# Tu función es:  -2 ^ 2 + 3 * -2 + 3 = [1]
# Tu función es:  -1 ^ 2 + 3 * -1 + 3 = [1]
# Tu función es:  0 ^ 2 + 3 * 0 + 3 = [3]
# Tu función es:  1 ^ 2 + 3 * 1 + 3 = [7]
# Tu función es:  2 ^ 2 + 3 * 2 + 3 = [13]
# Tu función es:  3 ^ 2 + 3 * 3 + 3 = [21]
# Los valores guardados son:  [[7], [3], [1], [1], [3], [7], [13], [21]]
